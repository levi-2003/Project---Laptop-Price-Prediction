# %% [markdown]
# <a href="https://colab.research.google.com/github/levi-2003/Project---Laptop-Price-Prediction/blob/main/Laptop_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("https://github.com/levi-2003/Project---Laptop-Price-Prediction/raw/main/laptop_price.csv", encoding='latin')

df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
df.sample()
# Out:
#     Company        Product            TypeName  Inches  \
# 727    Dell  Inspiron 5378  2 in 1 Convertible    13.3
#
#                     ScreenResolution                         Cpu  Ram  \
# 727  Full HD / Touchscreen 1920x1080  Intel Core i3 7100U 2.4GHz  4GB
#
#       Memory                    Gpu       OpSys  Weight  Price_euros
# 727  1TB HDD  Intel HD Graphics 620  Windows 10  1.71kg        649.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   Product           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price_euros       1303 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 122.3+ KB

# %%
df.isnull().sum()
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 28

# %%
df[df.duplicated()]
# Out:
#      Company                                    Product            TypeName  \
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1286  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1287      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1288    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1289    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1290    Dell                              Inspiron 3567            Notebook
# 1291    Acer                             Aspire ES1-531            Notebook
# 1292    Dell                              Inspiron 3552            Notebook
# 1293  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1294      HP                        Pavilion 15-AW003nv            Notebook
# 1295    Dell                              Inspiron 3567            Notebook
# 1296      HP                           Stream 11-Y000na             Netbook
# 1297    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1298  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1301      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Inches                            ScreenResolution  \
# 1275    13.3                 IPS Panel Full HD 1920x1080
# 1276    15.6                                    1366x768
# 1277    15.6                                    1366x768
# 1278    15.6                                    1366x768
# 1279    15.6                 IPS Panel Full HD 1920x1080
# 1280    15.6                           Full HD 1920x1080
# 1281    15.6                                    1366x768
# 1282    11.6                                    1366x768
# 1283    15.6                                    1366x768
# 1284    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1285    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286    14.0                                    1366x768
# 1287    15.6                                    1366x768
# 1288    15.6                                    1366x768
# 1289    13.3                 IPS Panel Full HD 1920x1080
# 1290    15.6                                    1366x768
# 1291    15.6                                    1366x768
# 1292    15.6                                    1366x768
# 1293    15.6                 IPS Panel Full HD 1920x1080
# 1294    15.6                           Full HD 1920x1080
# 1295    15.6                                    1366x768
# 1296    11.6                                    1366x768
# 1297    15.6                                    1366x768
# 1298    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300    14.0                                    1366x768
# 1301    15.6                                    1366x768
# 1302    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1275              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                           Gpu       OpSys  Weight  Price_euros
# 1275    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1276    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1277    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1278        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1279  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1280       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1281       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1282    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1283      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1284    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1285    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1286        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1287       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1288        Intel HD Graphics  Windows 10   2.2kg       369.00
# 1289    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1290    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1291    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1292        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1293  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1294       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1295       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1296    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1297      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1298    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302        Intel HD Graphics  Windows 10   2.2kg       369.00

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1275, 12)

# %%
df['Price']=(df['Price_euros']*90.96).astype('int')
df.drop(columns=['Price_euros'],inplace=True)

# %%
df.sample()
# Out:
#     Company        Product  TypeName  Inches   ScreenResolution  \
# 337      HP  Elitebook 850  Notebook    15.6  Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 337  Intel Core i5 7200U 2.5GHz  8GB  256GB SSD  Intel HD Graphics 620
#
#           OpSys  Weight   Price
# 337  Windows 10  1.84kg  104058

# %%
# EDA
# - Univariate Analysis
# - Multi-Variate Analysis

# %%
# Company Column
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
9+7+7+6+4+4+3+3+3+3+2
# Out:
# 51

# %%
plt.rcParams['figure.figsize']=[6,3.5]  # The default setting for entire notebook
# plt.figure(figsize=(10,8)) # individual graphs

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df=df[df.groupby('Company').Company.transform('count')>10].copy()

# %%
1275-1224
# Out:
# 51

# %%
df.shape
# Out:
# (1224, 12)

# %%
df=df.reset_index(drop=True)

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
sns.barplot(x=df['Company'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                 30
# Inspiron 3567                          25
# 250 G6                                 21
# Legion Y520-15IKBN                     19
# Vostro 3568                            19
#                                        ..
# Ideapad 520-15IKBR                      1
# Thinkpad X260                           1
# Rog G752VL-UH71T                        1
# Portege X30-D-10L                       1
# X553SA-XX031T (N3050/4GB/500GB/W10)     1
# Name: count, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)

# %%
df.sample()
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 832  Toshiba  Notebook    15.6  IPS Panel Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 832  Intel Core i7 7500U 2.7GHz  8GB  256GB SSD  Intel HD Graphics 620
#
#           OpSys Weight   Price
# 832  Windows 10  2.0kg  126252

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
# 15.6 : 15 inch
# 14.0 : 14 inch
# 17.3 : 17 inch
# 13.3 : 13 inch

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.displot(x=df['Inches'],kde=True)

# %%
sns.barplot(x=df['Inches'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Touchscreen 1920x1200                    4
# 1440x900                                           4
# IPS Panel Retina Display 2880x1800                 4
# IPS Panel 2560x1440                                4
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 3200x1800                       2
# 1920x1080                                          2
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# IPS Panel Full HD 2560x1440                        1
# IPS Panel Full HD 1366x768                         1
# Touchscreen / Quad HD+ 3200x1800                   1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
# X_res  : horizontal pixels
# Y_res  : vertical pixels
# IPS    : IPS panel or not
# Touchscreen : Touchscreen or not

# %%
a="IPS Panel Full HD / Touchscreen 1920x1080"

# %%
a.split()
# Out:
# ['IPS', 'Panel', 'Full', 'HD', '/', 'Touchscreen', '1920x1080']

# %%
a.split()[-1]
# Out:
# '1920x1080'

# %%
a.split()[-1].split('x')
# Out:
# ['1920', '1080']

# %%
a.split()[-1].split('x')[0]
# Out:
# '1920'

# %%
a.split()[-1].split('x')[1]
# Out:
# '1080'

# %%
(lambda x:x.split()[-1].split('x')[0])("IPS Panel Full HD / Touchscreen 1920x1080")
# Out:
# '1920'

# %%
(lambda x:x.split()[-1].split('x')[1])("IPS Panel Full HD / Touchscreen 1920x1080")
# Out:
# '1080'

# %%
(lambda x:1 if "IPS" in x else 0)(" Panel Full HD /  1920x1080")
# Out:
# 0

# %%
df['X_res']=df['ScreenResolution'].apply(lambda x:x.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda x:x.split()[-1].split('x')[1]).astype('int')
df['Touchscreen']=df['ScreenResolution'].apply(lambda x:1 if "Touchscreen" in x else 0).astype('int')
df['IPS']=df['ScreenResolution'].apply(lambda x:1 if "IPS" in x else 0).astype('int')

# %%
df.sample(6)
# Out:
#      Company   TypeName  Inches             ScreenResolution  \
# 1145      HP   Notebook    15.6  IPS Panel Full HD 1920x1080
# 471     Asus  Ultrabook    12.5            Full HD 1920x1080
# 311       HP   Notebook    14.0            Full HD 1920x1080
# 1000     MSI     Gaming    17.3  IPS Panel Full HD 1920x1080
# 183     Acer  Ultrabook    13.3  IPS Panel Full HD 1920x1080
# 65        HP   Notebook    15.6                     1366x768
#
#                               Cpu   Ram                Memory  \
# 1145  Intel Core i7 7700HQ 2.8GHz  12GB  128GB SSD +  1TB HDD
# 471    Intel Core i7 7500U 2.7GHz  16GB             512GB SSD
# 311    Intel Core i7 7500U 2.7GHz   8GB             256GB SSD
# 1000  Intel Core i7 6820HK 2.7GHz  16GB  256GB SSD +  1TB HDD
# 183     Intel Core i5 7Y54 1.2GHz   8GB             256GB SSD
# 65       Intel Core i3 6006U 2GHz   4GB             500GB HDD
#
#                           Gpu       OpSys  Weight   Price  X_res  Y_res  \
# 1145  Nvidia GeForce GTX 1050  Windows 10  2.21kg  120703   1920   1080
# 471     Intel HD Graphics 620  Windows 10  0.91kg  177372   1920   1080
# 311     Intel HD Graphics 620  Windows 10  1.48kg  117520   1920   1080
# 1000  Nvidia GeForce GTX 980M  Windows 10  3.78kg  140591   1920   1080
# 183     Intel HD Graphics 615  Windows 10  1.12kg   89959   1920   1080
# 65             AMD Radeon 520  Windows 10  1.86kg   39903   1366    768
#
#       Touchscreen  IPS
# 1145            0    1
# 471             0    0
# 311             0    0
# 1000            0    1
# 183             0    1
# 65              0    0

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches                         Cpu   Ram   Memory  \
# 276    Acer  Notebook    15.6  Intel Core i7 7500U 2.7GHz  12GB  1TB HDD
#
#                        Gpu       OpSys  Weight  Price  X_res  Y_res  \
# 276  Intel HD Graphics 620  Windows 10  2.15kg  59942   1920   1080
#
#      Touchscreen  IPS
# 276            1    1

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     595
# 4GB     351
# 16GB    186
# 6GB      34
# 12GB     25
# 32GB     15
# 2GB      14
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     595
# 4     351
# 16    186
# 6      34
# 12     25
# 32     15
# 2      14
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     124
# Intel Core i7 8550U 1.8GHz      71
# Intel Core i5 8250U 1.6GHz      71
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core M M3-6Y30 0.9GHz      1
# Intel Core i5 2.9GHz             1
# Intel Atom x5-Z8350 1.44GHz      1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 111, dtype: int64

# %%
a="Intel Core i5 8250U 1.6GHz"

# %%
(lambda a:" ".join(a.split()[0:3]))("Intel Core i5 8250U 1.6GHz")
# Out:
# 'Intel Core i5'

# %%
df['Cpu']=df['Cpu'].apply(lambda a:" ".join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# Intel Atom x5-Z8350           1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: count, dtype: int64

# %%
def fetch_processor_name(text):
  if text=='Intel Core i7' or text=='Intel Core i5' or text=='Intel Core i3' or text=='Intel Core M':
    return text
  elif text.split()[0]=='Intel':
    return " ".join(text.split()[0:2])
  else:
    return "AMD Processor"

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor_name)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7    493
# Intel Core i5    411
# Intel Core i3    134
# Intel Celeron     71
# AMD Processor     60
# Intel Pentium     30
# Intel Core M      16
# Intel Atom         5
# Intel Xeon         4
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x=df['Cpu'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 512GB SSD +  512GB SSD             1
# 512GB SSD +  256GB SSD             1
# 64GB Flash Storage +  1TB HDD      1
# 64GB SSD                           1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# -- Due to complexity in handling various storage options, we will skip the memory column

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram                    Gpu  \
# 638    Dell  Notebook    15.6  Intel Core i5    8  Intel HD Graphics 620
#
#           OpSys  Weight  Price  X_res  Y_res  Touchscreen  IPS
# 638  Windows 10  2.06kg  86866   1920   1080            0    0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# Intel Graphics 620           1
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel     666
# Nvidia    385
# AMD       173
# Name: count, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
sns.barplot(x=df['Gpu'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Android            2
# Windows 10 S       2
# Name: count, dtype: int64

# %%
def fetch_os(text):
  if text=="Windows 10" or text=="Windows 10 S":
    return "Windows 10"
  elif text=="Windows 7":
    return text
  elif text=="Mac OS X" or text=="macOS":
    return "Mac OS"
  else:
    return "Linux/No OS/Others"

# %%
df['OpSys']=df['OpSys'].apply(fetch_os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10            1013
# Linux/No OS/Others     145
# Windows 7               45
# Mac OS                  21
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
sns.barplot(x=df['OpSys'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['Weight']
# Out:
# 0       1.37kg
# 1       1.34kg
# 2       1.86kg
# 3       1.83kg
# 4       1.37kg
#          ...
# 1219     1.8kg
# 1220     1.3kg
# 1221     1.5kg
# 1222    2.19kg
# 1223     2.2kg
# Name: Weight, Length: 1224, dtype: object

# %%
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
sns.displot(x=df['Weight'],kde=True)

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram    Gpu       OpSys  Weight  \
# 557    Dell  Notebook    15.6  Intel Core i5    8  Intel  Windows 10     1.9
#
#      Price  X_res  Y_res  Touchscreen  IPS
# 557  91734   1366    768            0    0

# %%
df['Touchscreen'].value_counts()
# Out:
# Touchscreen
# 0    1055
# 1     169
# Name: count, dtype: int64

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'],errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                Inches       Ram    Weight     Price     X_res     Y_res  \
# Inches       1.000000  0.239155  0.824959  0.055330 -0.057739 -0.071772
# Ram          0.239155  1.000000  0.394187  0.726639  0.415731  0.412278
# Weight       0.824959  0.394187  1.000000  0.212038 -0.025155 -0.036765
# Price        0.055330  0.726639  0.212038  1.000000  0.553707  0.552964
# X_res       -0.057739  0.415731 -0.025155  0.553707  1.000000  0.997454
# Y_res       -0.071772  0.412278 -0.036765  0.552964  0.997454  1.000000
# Touchscreen -0.359497  0.094037 -0.291506  0.161443  0.320954  0.317174
# IPS         -0.104090  0.223322  0.038753  0.289226  0.283969  0.294360
#
#              Touchscreen       IPS
# Inches         -0.359497 -0.104090
# Ram             0.094037  0.223322
# Weight         -0.291506  0.038753
# Price           0.161443  0.289226
# X_res           0.320954  0.283969
# Y_res           0.317174  0.294360
# Touchscreen     1.000000  0.154500
# IPS             0.154500  1.000000

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# Touchscreen    0.161443
# IPS            0.289226
# Name: Price, dtype: float64

# %%
# Pixel density(ppi) is a much better measure than X_res and Y_res

# %%
df['ppi']=round(((df['X_res']**2)+(df['Y_res']**2))**0.5/df['Inches']).astype('int')

# %%
df['ppi']
# Out:
# 0       227
# 1       128
# 2       141
# 3       221
# 4       227
#        ...
# 1219    157
# 1220    276
# 1221    112
# 1222    100
# 1223    100
# Name: ppi, Length: 1224, dtype: int64

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055330
# Ram            0.726639
# Weight         0.212038
# Price          1.000000
# X_res          0.553707
# Y_res          0.552964
# Touchscreen    0.161443
# IPS            0.289226
# ppi            0.483821
# Name: Price, dtype: float64

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df['ppi'].value_counts()
# Out:
# ppi
# 141    419
# 100    195
# 127    131
# 157    122
# 166    100
# 112     42
# 135     28
# 176     25
# 276     25
# 282     23
# 106     22
# 210     18
# 125      9
# 118      8
# 331      7
# 227      6
# 226      6
# 221      6
# 255      5
# 128      4
# 224      4
# 158      4
# 317      2
# 170      2
# 91       2
# 352      2
# 190      1
# 108      1
# 120      1
# 111      1
# 195      1
# 235      1
# 147      1
# Name: count, dtype: int64

# %%
sns.displot(x=df['ppi'],kde=True)

# %%
sns.scatterplot(x=df['ppi'],y=df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company TypeName            Cpu  Ram    Gpu       OpSys  Weight  Price  \
# 665    Acer  Netbook  Intel Celeron    4  Intel  Windows 10     1.4  24468
#
#      Touchscreen  IPS  ppi
# 665            0    0  135

# %%
df.shape
# Out:
# (1224, 11)

# %%
df.to_csv("laptop_data_cleaned.csv",index=False)

# %%
sns.displot(x=df['Price'],kde=True)
plt.show()

# %%
sns.displot(x=np.log(df['Price']),kde=True)
plt.show()

# %%
X=df.drop(columns=['Price'])
y=np.log(df['Price'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=42)

# %%
X.shape
# Out:
# (1224, 10)

# %%
X_train.shape
# Out:
# (1040, 10)

# %%
X_test.shape
# Out:
# (184, 10)

# %%
1224*0.85
# Out:
# 1040.3999999999999

# %%
X.head()
# Out:
#   Company   TypeName            Cpu  Ram    Gpu               OpSys  Weight  \
# 0   Apple  Ultrabook  Intel Core i5    8  Intel              Mac OS    1.37
# 1   Apple  Ultrabook  Intel Core i5    8  Intel              Mac OS    1.34
# 2      HP   Notebook  Intel Core i5    8  Intel  Linux/No OS/Others    1.86
# 3   Apple  Ultrabook  Intel Core i7   16    AMD              Mac OS    1.83
# 4   Apple  Ultrabook  Intel Core i5    8  Intel              Mac OS    1.37
#
#    Touchscreen  IPS  ppi
# 0            0    1  227
# 1            0    0  128
# 2            0    0  141
# 3            0    1  221
# 4            0    1  227

# %%
X_train.head()
# Out:
#     Company   TypeName            Cpu  Ram     Gpu       OpSys  Weight  \
# 240   Apple  Ultrabook  Intel Core i5    8   Intel      Mac OS    1.37
# 439  Lenovo   Notebook  Intel Core i5    8   Intel  Windows 10    1.65
# 192    Dell     Gaming  Intel Core i7   16  Nvidia  Windows 10    2.65
# 218    Asus   Notebook  Intel Core i5    8  Nvidia  Windows 10    2.00
# 184    Dell   Notebook  Intel Core i7    8     AMD  Windows 10    2.80
#
#      Touchscreen  IPS  ppi
# 240            0    1  227
# 439            0    0  157
# 192            0    1  282
# 218            0    0  141
# 184            0    0  127

# %%
y_train.head()
# Out:
# 240    12.131123
# 439    11.714568
# 192    12.030653
# 218    11.155507
# 184    11.499749
# Name: Price, dtype: float64

# %%
X_test.head()
# Out:
#     Company            TypeName            Cpu  Ram     Gpu       OpSys  \
# 661  Lenovo            Notebook  Intel Core i5    4   Intel  Windows 10
# 220      HP            Notebook  Intel Core i7    8     AMD  Windows 10
# 155    Dell  2 in 1 Convertible  Intel Core i7    8   Intel  Windows 10
# 677  Lenovo         Workstation  Intel Core i7   16  Nvidia   Windows 7
# 911    Dell  2 in 1 Convertible  Intel Core i5    8   Intel  Windows 10
#
#      Weight  Touchscreen  IPS  ppi
# 661    1.70            0    0  157
# 220    1.90            0    0  141
# 155    1.56            1    0  141
# 677    2.18            0    0  141
# 911    1.24            1    0  166

# %%
y_test.head()
# Out:
# 661    11.060070
# 220    11.656402
# 155    11.466012
# 677    12.036055
# 911    12.059502
# Name: Price, dtype: float64

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
X_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram    Gpu       OpSys  Weight  \
# 575      HP  Notebook  Intel Core i7    8  Intel  Windows 10    1.84
#
#      Touchscreen  IPS  ppi
# 575            0    0  141

# %%
# LinearRegression
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=LinearRegression()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7849854828706778
# MAE: 0.20009186638712761
# MSE: 0.0678906670648767

# %%
# Lasso
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=Lasso(alpha=0.001)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7924904607933325
# MAE: 0.19507784204024442
# MSE: 0.06552097610503446

# %%
# Ridge
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=Ridge(alpha=8)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7911478899674752
# MAE: 0.19647484813345845
# MSE: 0.06594489180229166

# %%
# KNeighborsRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=KNeighborsRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7859697023952642
# MAE: 0.1926773629893376
# MSE: 0.06757990051313613

# %%
# DecisionTreeRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=DecisionTreeRegressor(max_depth=8)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.807079216027232
# MAE: 0.18501330302885954
# MSE: 0.06091458795181066

# %%
# Support Vector Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=SVR(C=10000)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8144162220880313
# MAE: 0.1811312900754648
# MSE: 0.05859793397710663

# %%
# AdaBoostRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=AdaBoostRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8082297003725412
# MAE: 0.19577278440990448
# MSE: 0.06055132341184586

# %%
# RandomForestRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=RandomForestRegressor()
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8643225633418082
# MAE: 0.15988390945468728
# MSE: 0.042840045422779645

# %%
# eXtreme Gradient Boosting Regressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=XGBRegressor(n_estimators=50,max_depth=4)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8775469222718489
# MAE: 0.14592216222317725
# MSE: 0.03866446434456888

# %%
# GradientBoostingRegressor
step1=ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,2,4,5])
    ],remainder='passthrough')
step2=GradientBoostingRegressor(n_estimators=300)
pipe=Pipeline([('step1',step1),('step2',step2)])
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)

print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.880001536817185
# MAE: 0.14460056121041998
# MSE: 0.037889421705146614

# %%
import pickle
pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
# !pip install streamlit --quiet

# %%
# %%writefile app.py
import streamlit as st
import pickle
import numpy as np
from math import exp

df=pickle.load(open('df.pkl','rb'))
pipe=pickle.load(open('pipe.pkl','rb'))

st.title("Laptop Price Predictor")
company=st.selectbox("Brand",df['Company'].unique(),index=4)
typenote=st.selectbox("Type",df['TypeName'].unique(),index=1)
cpu=st.selectbox("Processor",df['Cpu'].unique(),index=0)
ram=st.selectbox("RAM(in GB)",[2,4,6,8,12,16,24,32,64,128],index=3)
gpu=st.selectbox("GPU",df['Gpu'].unique(),index=0)
os=st.selectbox("Operating system",df['OpSys'].unique(),index=0)
weight=st.select_slider("Weight",options=np.linspace(0,4,8).round(2))
ips=st.radio("IPS DISPLAY",['YES','NO'])
t=st.radio("Touchscreen",['YES','NO'])
ppi=st.select_slider("PPI",options=np.linspace(100,280,180))
if ips=='YES' : ips=1
else: ips=0
if t=='YES' : t=1
else: t=0
if st.button('Predict'):
    pred=np.array([[company,typenote,cpu,ram,gpu,os,weight,t,ips,ppi]])
    predicted=pipe.predict(pred)
    st.write('the predicted Price is Rs',round(exp(predicted[0])))
# Out:
# Overwriting app.py

# %%
X_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram  Gpu               OpSys  Weight  \
# 100    Dell  Notebook  Intel Core i5    8  AMD  Linux/No OS/Others     2.2
#
#      Touchscreen  IPS  ppi
# 100            0    0  141

# %%
df['Gpu'].unique()
# Out:
# array(['Intel', 'AMD', 'Nvidia'], dtype=object)

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.232.123.150:8501
#
# npx: installed 22 in 2.134s
# your url is: https://spotty-wings-move.loca.lt
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
